# %% [markdown]
# <a href="https://colab.research.google.com/github/mallenarayana/Fmml_Course_Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-01 16:06:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   197MB/s    in 0.4s
#
# 2024-05-01 16:06:21 (197 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9177   1603.06679v3  In aspect-based sentiment analysis, extracting...    cs
# 3968    0804.0353v1  This paper pursues some applications of Rough ...    cs
# 34214   1404.1982v1  Text is the main method of communicating infor...    cs
# 6951   1708.00524v2  NLP tasks are often limited by scarcity of man...  stat
# 2315   1803.04674v1  In this work, we provide theoretical guarantee...    cs
# ...             ...                                                ...   ...
# 1981   1803.08137v1  We revisit the Blind Deconvolution problem wit...    cs
# 17474  1711.05345v2  Although transfer learning has been shown to b...    cs
# 9188   1607.01958v1  Efficient Market Hypothesis is the popular the...    cs
# 33639   1412.5862v1  Network of neurons in the brain apply - unlike...    cs
# 7944   1607.02857v1  We trained a deep all-convolutional neural net...    cs
#
#                                                    title  year  \
# 9177   Recursive Neural Conditional Random Fields for...  2016
# 3968   Graphical Estimation of Permeability Using RST...  2008
# 34214  Aspect-Based Opinion Extraction from Customer ...  2014
# 6951   Using millions of emoji occurrences to learn a...  2017
# 2315   Hierarchical Reinforcement Learning: Approxima...  2018
# ...                                                  ...   ...
# 1981       Robust Blind Deconvolution via Mirror Descent  2018
# 17474  Supervised and Unsupervised Transfer Learning ...  2017
# 9188   Stock trend prediction using news sentiment an...  2016
# 33639  A theoretical basis for efficient computations...  2014
# 7944   Classifying Variable-Length Audio Files with A...  2016
#
#                                                 keywords
# 9177   [sentiment, extracting, expressed, generated, ...
# 3968   [applications, organizing, processing, variati...
# 34214  [communicating, information, opinionated, info...
# 6951   [annotated, sentiment, researchers, therefore,...
# 2315   [theoretical, guarantees, decomposition, deter...
# ...                                                  ...
# 1981   [deconvolution, understanding, robustness, con...
# 17474  [successful, recognition, applicability, answe...
# 9188   [efficient, hypothesis, prediction, prediction...
# 33639  [processors, generation, processing, occurrenc...
# 7944   [convolutional, classification, classification...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9177     [sentiment, extracting, expressed, generated, ...
# 3968     [applications, organizing, processing, variati...
# 34214    [communicating, information, opinionated, info...
# 6951     [annotated, sentiment, researchers, therefore,...
# 2315     [theoretical, guarantees, decomposition, deter...
#                                ...
# 832      [increasingly, interaction, potentially, dange...
# 24130    [investigate, properties, determined, attribut...
# 21611    [generalization, regularizations, regularizati...
# 9512     [addresses, detecting, applications, understan...
# 1212     [competition, steganalysis, approaches, method...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8914 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e4d17909-2e47-4aad-ab6e-a7827c8f1ee5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4d17909-2e47-4aad-ab6e-a7827c8f1ee5")) {                    Plotly.newPlot(                        "e4d17909-2e47-4aad-ab6e-a7827c8f1ee5",                        [{"x":["exploiting","performance","generated","discriminative","framework","extraction","conditional","simultaneously","experimental","important","incorporate","challenge","connections","recursive","integrates","superiority","extracting","expressed","promising","sentiment","propagate","information","different","graphical","processing","combining","applications","variations","comparison","estimation","organizing","highlighted","inference","generates","representative","mechanism","enhancing","purchasing","contribution","displayed","summarize","techniques","decisions","similarity","sequentially","opinionated","ontologies","communicating","pretrained","diversity","detection","detecting","emotional","extending","researchers","prediction","containing","representations","improvement","emoticons","occurrences","benchmark","supervision","approaches","therefore","annotated","binarized","resources","stochastic","guarantee","deterministic","particular","approximate","theoretical","guarantees","implement","substantial","solutions","decomposition","discounted","approximating","computational","hierarchical","reinforcement","traveling","composite","approximation","statistical","convexity","corresponding","established","combinatorial","baselines","restricted","maximization","empirical","assumptions","submodular","smoothness","previously","optimization","reminiscent","additionally","dependency","represented","modifying","minimizing","convolution","computation","mobilenet","convolutional","improving","generalized","significantly","available","operation","resorting","definition","relations","considered","constructed","parameters","shufflenet","efficiency","successfully","convolutions","facilitate","semantically","embedding","superpixel","horizontal","foreground","categories","belonging","segmentation","demonstrate","instances","disparity","detectors","precision","classifies","background","perception","classification","variables","artificial","effectiveness","estimated","independence","violation","algorithm","consistently","simulated","influences","distorted","confounders","inferring","handwritten","renormalization","unlabeled","identified","perturbations","technique","automatically","distinguishability","experiments","component","requiring","computationally","measurement","recursively","divergence","trajectory","probability","estimating","trajectories","recursion","efficient","implementation","minimising","filtering","hypotheses","hypothesis","association","obtaining","principled","resulting","introduce","encourages","underspecified","languages","streamline","dependencies","lightweight","annotators","algorithms","representation","formalism","permitting","annotations"],"y":[85,853,169,109,554,168,87,89,371,357,57,153,58,29,31,47,73,25,122,43,5,701,757,59,272,111,404,89,128,203,14,8,200,54,26,109,19,2,85,10,22,363,61,132,15,3,22,8,9,41,345,81,14,26,68,232,68,242,146,2,19,231,55,422,130,80,5,79,125,37,47,257,125,161,66,73,52,139,60,7,17,311,90,117,5,16,129,154,10,131,57,47,72,41,28,167,62,7,14,98,325,0,53,56,70,5,48,41,144,2,378,120,82,259,295,42,6,44,85,119,58,248,2,158,87,14,43,36,113,9,5,17,61,11,195,564,93,8,36,78,12,73,45,515,135,146,198,64,27,3,821,45,63,8,6,0,28,30,2,46,48,15,225,175,1,593,104,44,89,23,12,21,16,148,67,31,2,387,135,2,68,32,49,29,36,26,152,337,7,2,87,2,61,7,6,583,345,29,5,57],"type":"bar"},{"x":["exploiting","performance","generated","discriminative","framework","extraction", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Impact</span> <span style=''>of</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>on</span> <span style=''>Micro</span> <span style=''>Text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>Social</span> <span style=''>media</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>Twitter</span> <span style=''>tweets</span> <span style=''>are</span> <span style=''>popular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Tweets</span> <span style=''>are</span> <span style=''>a</span> <span style=''>valuable</span> <span style=''>source</span> <span style=''>of</span> <span style=''>micro</span> <span style=''>text</span> <span style=''>(sometimes</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>micro</span> <span style=''>blogs)</span> <span style=''>and</span> <span style=''>have</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>domains</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.5357142857142856);'>sentiment</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>systems</span> <span style=''>spam</span> <span style='background-color:rgba(0, 255, 0, 0.5265486725663717);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>among</span> <span style=''>others</span> <span style=''>Tweets</span> <span style=''>often</span> <span style=''>include</span> <span style=''>keywords</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>Hashtags</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style=''>labels</span> <span style=''>for</span> <span style=''>the</span> <span style=''>tweet</span> <span style=''>Using</span> <span style=''>tweets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encompassing</span> <span style=''>50</span> <span style=''>labels</span> <span style=''>we</span> <span style=''>studied</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>word</span> <span style=''>versus</span> <span style='background-color:rgba(0, 255, 0, 0.709090909090909);'>character</span> <span style=''>level</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6231884057971013);'>extraction</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.34817453250222624);'>different</span> <span style=''>learners</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>task</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.6231884057971013);'>extraction</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.709090909090909);'>character</span> <span style=''>level</span> <span style=''>groups</span> <span style=''>performs</span> <span style=''>better</span> <span style=''>than</span> <span style=''>simple</span> <span style=''>word</span> <span style=''>groups</span> <span style=''>and</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>modeling</span> <span style=''>In</span> <span style=''>the</span> <span style=''>discrete</span> <span style=''>case</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>binary</span> <span style=''>or</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>alphabet</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>are</span> <span style=''>already</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>since</span> <span style=''>the</span> <span style=''>cliques</span> <span style=''>can</span> <span style=''>take</span> <span style=''>only</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style=''>values</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Continuous</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>The</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>is</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>data</span> <span style=''>but</span> <span style=''>it</span> <span style=''>makes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrealistic</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>building</span> <span style=''>more</span> <span style=''>flexible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>One</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>the</span> <span style=''>other</span> <span style=''>uses</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricts</span> <span style=''>the</span> <span style=''>graphs</span> <span style=''>to</span> <span style=''>trees</span> <span style=''>and</span> <span style=''>forests</span> <span style=''>Examples</span> <span style=''>of</span> <span style=''>both</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(255, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <br/><br/><span style=''>The</span> <span style=''>online</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>(MDP)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.36842105263157887);'>incorporates</span> <span style=''>changing</span> <span style=''>reward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>online</span> <span style=''>MDP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style='background-color:rgba(255, 0, 0, 0.3472222222222222);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sublinear</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>A</span> <span style=''>notable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>large</span> <span style=''>and</span> <span style=''>possibly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>handled</span> <span style=''>Through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>usefulness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Compose</span> <span style=''>Domain</span> <span style=''>Specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transformations</span> <span style=''>for</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Augmentation</span> <br/><br/><span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmentation</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ubiquitous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>sets</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>that</span> <span style=''>preserve</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>While</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style=''>easy</span> <span style=''>for</span> <span style=''>domain</span> <span style=''>experts</span> <span style=''>to</span> <span style=''>specify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>and</span> <span style=''>tuning</span> <span style=''>the</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compositions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>is</span> <span style=''>a</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>manual</span> <span style=''>task</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automating</span> <span style=''>this</span> <span style=''>process</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>sequence</span> <span style=''>model</span> <span style=''>over</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>approach</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style='background-color:rgba(0, 255, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1327845382963493)
# 	automatic (0.06979241231209735)
# 	knowledge (0.12705798138869004)
# 	segmentation (0.06979241231209735)
# 	architecture (0.09162491052254831)
# 	information (0.25089477451682174)
# 	detection (0.12347888332140301)
# 	different (0.27093772369362923)
# 	convolutional (0.13528990694345025)
# 	recognition (0.1377952755905512)
#
# Some Statistics words are:
# 	variables (0.13260219341974078)
# 	statistical (0.14456630109670987)
# 	theoretical (0.15453639082751744)
# 	stochastic (0.14356929212362912)
# 	estimation (0.17347956131605186)
# 	algorithm (0.3988035892323031)
# 	distribution (0.18544366899302095)
# 	dimensional (0.1889332003988036)
# 	inference (0.20189431704885344)
# 	regression (0.1769690927218345)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01d863e4-f746-429f-8a7d-68a949782b22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d863e4-f746-429f-8a7d-68a949782b22")) {                    Plotly.newPlot(                        "01d863e4-f746-429f-8a7d-68a949782b22",                        [{"x":["exploiting","performance","generated","discriminative","framework","extraction","conditional","simultaneously","experimental","important","incorporate","challenge","connections","recursive","integrates","superiority","extracting","expressed","promising","sentiment","propagate","information","different","graphical","processing","combining","applications","variations","comparison","estimation","organizing","highlighted","inference","generates","representative","mechanism","enhancing","purchasing","contribution","displayed","summarize","techniques","decisions","similarity","sequentially","opinionated","ontologies","communicating","pretrained","diversity","detection","detecting","emotional","extending","researchers","prediction","containing","representations","improvement","emoticons","occurrences","benchmark","supervision","approaches","therefore","annotated","binarized","resources","stochastic","guarantee","deterministic","particular","approximate","theoretical","guarantees","implement","substantial","solutions","decomposition","discounted","approximating","computational","hierarchical","reinforcement","traveling","composite","approximation","statistical","convexity","corresponding","established","combinatorial","baselines","restricted","maximization","empirical","assumptions","submodular","smoothness","previously","optimization","reminiscent","additionally","dependency","represented","modifying","minimizing","convolution","computation","mobilenet","convolutional","improving","generalized","significantly","available","operation","resorting","definition","relations","considered","constructed","parameters","shufflenet","efficiency","successfully","convolutions","facilitate","semantically","embedding","superpixel","horizontal","foreground","categories","belonging","segmentation","demonstrate","instances","disparity","detectors","precision","classifies","background","perception","classification","variables","artificial","effectiveness","estimated","independence","violation","algorithm","consistently","simulated","influences","distorted","confounders","inferring","handwritten","renormalization","unlabeled","identified","perturbations","technique","automatically","distinguishability","experiments","component","requiring","computationally","measurement","recursively","divergence","trajectory","probability","estimating","trajectories","recursion","efficient","implementation","minimising","filtering","hypotheses","hypothesis","association","obtaining","principled","resulting","introduce","encourages","underspecified","languages","streamline","dependencies","lightweight","annotators","algorithms","representation","formalism","permitting","annotations","annotation","paradigms","businesses","technologies","governments","processes","institutions","education","explosion","computing","extensively","interactions","selection","conditions","intelligent","databases","companies","organizations","generation","necessitates","management","scenarios","cooperators","exploitation","defectors","behaviour","emergence","favourable","performed","environment","understanding","competition","coevolutionary","prisoners","cooperative","configurations","cooperation","protection","dominance","abstainers","simulation","challenging","considering","algorithmic","assessment","structure","widespread","structural","knowledge","characteristics","continuous","quantitative","heuristics","investigate","complicated" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reminiscent
# 	confounders
# 	unequally
# 	blockmodel
# 	collinearity
# 	collapsing
# 	monetization
# 	distributedly
# 	triangular
# 	ellipsoidal
# 	percentile
# 	statistician
# 	gaussianity
# 	manageable
# 	compromised
# 	homoscedastic
# 	borrowings
# 	dendrogram
# 	heteroscedasticity
# 	hypergraphs
# Some words which never appear in Statistics papers:
# 	opinionated
# 	traveling
# 	mobilenet
# 	shufflenet
# 	superpixel
# 	renormalization
# 	organizations
# 	cooperators
# 	defectors
# 	coevolutionary
# 	prisoners
# 	abstainers
# 	upsampling
# 	upsampled
# 	upsamples
# 	topologically
# 	epithelial
# 	detachment
# 	reviewers
# 	consecutively

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077585941587419e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
